# %% [markdown]
# #### Introduction

# %% [markdown]
# - In this project, I will analyze TMDB Dataset and communicate my findings using Numpy, Pandas and Seaborn Python Library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# - Data Wrangling

# %%
#Load dataset and view the first 5 dataset
df = pd.read_csv(r"C:\Users\BOUQSESH-PC\Downloads\tmdb-movies.csv")
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %% [markdown]
# The dataset contains 10866 rows and 21 columns

# %%
# inspect data types and look for instance of missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# ScheduledDay and AppointmentDay should be datetime  and not object as above.

# %%
# check for missing data
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# The data has no missing data

# %%
# summary statistics of the dataset
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# - The mean of the age is 37years
# - The maximum age is 115years
# - The minimum age is -1 and it is impossible to have an age of -1 (Probably a data entry error)

# %%
#check for duplicate rows
sum(df.duplicated())
# Out:
# 1

# %%
#Drop duplicate row
df.drop_duplicates(inplace=True)

# %%
#Drop column that are not necessary for the analysis
df.drop(["imdb_id","homepage","tagline","overview"],axis=1,inplace=True)

# %%
#check for last rows of datasets
df.tail()
# Out:
#           id  popularity  budget  revenue            original_title  \
# 10861     21    0.080598       0        0        The Endless Summer
# 10862  20379    0.065543       0        0                Grand Prix
# 10863  39768    0.065141       0        0       Beregis Avtomobilya
# 10864  21449    0.064317       0        0    What's Up, Tiger Lily?
# 10865  22293    0.035919   19000        0  Manos: The Hands of Fate
#
#                                                     cast            director  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...         Bruce Brown
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...  John Frankenheimer
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      Eldar Ryazanov
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...         Woody Allen
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...    Harold P. Warren
#
#                                   keywords  runtime                  genres  \
# ...

# %%
#change date from integer to datetime
df['release_date']=pd.to_datetime(df['release_date'],errors='coerce').dt.time

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Which year has the lowest release of movies?

# %%
df.groupby("release_year").count()["id"].sort_values(ascending=True)
# Out:
# release_year
# 1961     31
# 1969     31
# 1960     32
# 1962     32
# 1963     34
# 1965     35
# 1968     39
# 1967     40
# 1972     40
# 1970     41
# 1964     42
# 1975     44
# 1966     46
# 1976     47
# 1974     47
# 1973     55
# 1971     55
# 1977     57
# 1979     57
# 1978     65
# 1980     78
# 1983     80
# 1982     81
# 1981     82
# 1984    105
# 1985    109
# 1986    121
# 1987    125
# 1990    132
# 1991    133
# 1992    133
# 1989    137
# 1988    145
# 1995    175
# 1993    178
# 1994    184
# 1997    192
# 1996    204
# 1998    210
# 1999    224
# 2000    227
# 2001    242
# 2002    266
# 2003    281
# 2004    307
# 2005    364
# 2006    408
# 2007    438
# 2010    489
# 2008    496
# 2009    533
# 2011    540
# 2012    588
# 2015    629
# 2013    659
# 2014    700
# Name: id, dtype: int64

# %% [markdown]
# The year with the lowest amount of movies are 1961 and 1969

# %% [markdown]
# #### Q2 Which Month has the highest released of movies in all of the years?

# %%
df['release_date'].dt.month.value_counts()
# Out:
# Series([], Name: release_date, dtype: int64)

# %%
from scipy.stats import uniform
uniform.cdf(7,0,12)
# Out:
# 0.5833333333333334
